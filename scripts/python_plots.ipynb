# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the range of input sizes (n)
n_values = np.linspace(1, 6, 100)

# Define the corresponding execution times for each complexity class
constant_time = np.ones_like(n_values)
logarithmic_time = np.log(n_values)
sublinear_time = np.sqrt(n_values)
linearithmic_time = n_values * np.log(n_values)
linear_time = n_values
polynomial_time = n_values ** 2
quadratic_time = n_values ** 2
cubic_time = n_values ** 3
exponential_time = 2 ** n_values
#factorial_time = np.math.factorial(n_values)

# %%
# https://vscode.dev/github/minoad/articles/blob/main/scripts/python_plots.ipynb#C3:L1
# Plot the lines
plt.figure(figsize=(10, 8))

# First graph
plt.subplot(2, 1, 1)

plt.plot(n_values, constant_time, label='Constant Time: $O(1)$', color='blue')
plt.plot(n_values, logarithmic_time, label='Logarithmic Time: $O(\log n)$', color='orange')
plt.plot(n_values, sublinear_time, label='Sublinear Time: $O(\sqrt{n})$', color='green')
plt.plot(n_values, linearithmic_time, label='Linearithmic Time: $O(n \log n)$', color='red')

# Add labels and title for the first graph
plt.xlabel('Input Size ($n$)', fontsize=12)
plt.ylabel('Execution Time', fontsize=12)
plt.title('Complexity Classes (First Graph)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True)

# Second graph
plt.subplot(2, 1, 2)

plt.plot(n_values, linear_time, label='Linear Time: $O(n)$', color='purple')
plt.plot(n_values, polynomial_time, label='Polynomial Time: $O(n^2)$', color='brown')
plt.plot(n_values, quadratic_time, label='Quadratic Time: $O(n^2)$', color='pink')
plt.plot(n_values, cubic_time, label='Cubic Time: $O(n^3)$', color='gray')
plt.plot(n_values, exponential_time, label='Exponential Time: $O(2^n)$', color='cyan')

# Add labels and title for the second graph
plt.xlabel('Input Size ($n$)', fontsize=12)
plt.ylabel('Execution Time', fontsize=12)
plt.title('Complexity Classes (Second Graph)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True)

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\l'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# <>:8: SyntaxWarning: invalid escape sequence '\l'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Micah\AppData\Local\Temp\ipykernel_29136\493907127.py:8: SyntaxWarning: invalid escape sequence '\l'
#   plt.plot(n_values, logarithmic_time, label='Logarithmic Time: $O(\log n)$', color='orange')
# C:\Users\Micah\AppData\Local\Temp\ipykernel_29136\493907127.py:9: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(n_values, sublinear_time, label='Sublinear Time: $O(\sqrt{n})$', color='green')
# C:\Users\Micah\AppData\Local\Temp\ipykernel_29136\493907127.py:10: SyntaxWarning: invalid escape sequence '\l'
#   plt.plot(n_values, linearithmic_time, label='Linearithmic Time: $O(n \log n)$', color='red')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of input sizes (n)
n_values = np.linspace(1, 100, 100)

# Constant time function (execution time remains constant)
constant_time = np.ones_like(n_values)

# Plot the constant time function
plt.figure(figsize=(4, 3))
plt.plot(n_values, constant_time, label='Constant Time: $O(1)$', color='blue')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=12)
plt.ylabel('Execution Time', fontsize=12)
plt.title('Constant Time Complexity', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True)

plt.savefig("../figures/constant_time.png", dpi=300)
# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of input sizes (n)
n_values = np.linspace(1, 100, 100)

# Linear time function (execution time grows linearly with input size)
linear_time = n_values

# Plot the linear time function
plt.figure(figsize=(4, 3))  # Half the original size
plt.plot(n_values, linear_time, label='Linear Time: $O(n)$', color='green')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=10)
plt.ylabel('Execution Time', fontsize=10)
plt.title('Linear Time Complexity', fontsize=12)
plt.legend(fontsize=8)
plt.grid(True)

# Save the plot as an image file
plt.savefig("../figures/linear_time.png", dpi=300)  # Save as PNG with 300 dpi resolution

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of input sizes (n)
n_values = np.linspace(1, 100, 100)

# Logarithmic time function (execution time grows logarithmically with input size)
logarithmic_time = np.log(n_values)

# Plot the logarithmic time function
plt.figure(figsize=(4, 3))  # Half the original size
plt.plot(n_values, logarithmic_time, label='Logarithmic Time: $O(\log n)$', color='blue')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=10)
plt.ylabel('Execution Time', fontsize=10)
plt.title('Logarithmic Time Complexity', fontsize=12)
plt.legend(fontsize=8)
plt.grid(True)

# Save the plot as an image file
plt.savefig("../figures/logarithmic_time.png", dpi=300)  # Save as PNG with 300 dpi resolution

# Show the plot
plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Micah\AppData\Local\Temp\ipykernel_29136\1395553828.py:12: SyntaxWarning: invalid escape sequence '\l'
#   plt.plot(n_values, logarithmic_time, label='Logarithmic Time: $O(\log n)$', color='blue')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of input sizes (n)
n_values = np.linspace(1, 100, 100)

# Linearithmic time function (execution time grows linearly and logarithmically with input size)
linearithmic_time = n_values * np.log(n_values)

# Plot the linearithmic time function
plt.figure(figsize=(4, 3))  # Half the original size
plt.plot(n_values, linearithmic_time, label='Linearithmic Time: $O(n \log n)$', color='green')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=10)
plt.ylabel('Execution Time', fontsize=10)
plt.title('Linearithmic Time Complexity', fontsize=12)
plt.legend(fontsize=8)
plt.grid(True)

# Save the plot as an image file
plt.savefig("../figures/linearithmic_time.png", dpi=300)  # Save as PNG with 300 dpi resolution

# Show the plot
plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Micah\AppData\Local\Temp\ipykernel_29136\2650458573.py:12: SyntaxWarning: invalid escape sequence '\l'
#   plt.plot(n_values, linearithmic_time, label='Linearithmic Time: $O(n \log n)$', color='green')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of input sizes (n)
n_values = np.linspace(1, 100, 100)

# Quadratic time function (execution time grows quadratically with input size)
quadratic_time = n_values ** 2

# Plot the quadratic time function
plt.figure(figsize=(4, 3))  # Half the original size
plt.plot(n_values, quadratic_time, label='Quadratic Time: $O(n^2)$', color='red')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=10)
plt.ylabel('Execution Time', fontsize=10)
plt.title('Quadratic Time Complexity', fontsize=12)
plt.legend(fontsize=8)
plt.grid(True)

# Save the plot as an image file
plt.savefig("../figures/quadratic_time.png", dpi=300)  # Save as PNG with 300 dpi resolution

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of input sizes (n)
n_values = np.linspace(1, 50, 100)

# Cubic time function (execution time grows cubically with input size)
cubic_time = n_values ** 3

# Plot the cubic time function
plt.figure(figsize=(4, 3))  # Half the original size
plt.plot(n_values, cubic_time, label='Cubic Time: $O(n^3)$', color='blue')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=10)
plt.ylabel('Execution Time', fontsize=10)
plt.title('Cubic Time Complexity', fontsize=12)
plt.legend(fontsize=8)
plt.grid(True)

# Save the plot as an image file
plt.savefig("../figures/cubic_time.png", dpi=300)  # Save as PNG with 300 dpi resolution

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of input sizes (n)
n_values = np.linspace(1, 50, 100)

# Polynomial time function (e.g., n^2)
k = 2  # You can change k to any other value for different polynomial complexities
polynomial_time = n_values ** k

# Plot the polynomial time function
plt.figure(figsize=(4, 3))  # Half the original size
plt.plot(n_values, polynomial_time, label=f'Polynomial Time: $O(n^{k})$', color='brown')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=10)
plt.ylabel('Execution Time', fontsize=10)
plt.title(f'Polynomial Time Complexity ($O(n^{k})$)', fontsize=12)
plt.legend(fontsize=8)
plt.grid(True)

# Save the plot as an image file
plt.savefig("../figures/polynomial_time.png", dpi=300)  # Save as PNG with 300 dpi resolution

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of input sizes (n)
n_values = np.linspace(1, 20, 100)

# Exponential time function (e.g., 2^n)
exponential_time = 2 ** n_values

# Plot the exponential time function
plt.figure(figsize=(4, 3))  # Half the original size
plt.plot(n_values, exponential_time, label='Exponential Time: $O(2^n)$', color='cyan')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=10)
plt.ylabel('Execution Time', fontsize=10)
plt.title('Exponential Time Complexity ($O(2^n)$)', fontsize=12)
plt.legend(fontsize=8)
plt.grid(True)

# Save the plot as an image file
plt.savefig('../figures/exponential_time.png', dpi=300)  # Save as PNG with 300 dpi resolution

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Define the range of input sizes (n)
n_values = np.linspace(1, 10, 100)

# Factorial time function
factorial_time = [math.factorial(int(n)) for n in n_values]

# Plot the factorial time function
plt.figure(figsize=(4, 3))  # Half the original size
plt.plot(n_values, factorial_time, label='Factorial Time: $O(n!)$', color='magenta')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=10)
plt.ylabel('Execution Time', fontsize=10)
plt.title('Factorial Time Complexity ($O(n!)$)', fontsize=12)
plt.legend(fontsize=8)
plt.grid(True)

# Save the plot as an image file
plt.savefig('../figures/factorial_time.png', dpi=300)  # Save as PNG with 300 dpi resolution

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of input sizes (n)
n_values = np.linspace(1, 100, 100)

# Sublinear time function
sublinear_time = np.sqrt(n_values)

# Plot the sublinear time function
plt.figure(figsize=(4, 3))  # Half the original size
plt.plot(n_values, sublinear_time, label='Sublinear Time: $O(\\sqrt{n})$', color='green')

# Add labels and title
plt.xlabel('Input Size ($n$)', fontsize=10)
plt.ylabel('Execution Time', fontsize=10)
plt.title('Sublinear Time Complexity ($O(\\sqrt{n})$)', fontsize=12)
plt.legend(fontsize=8)
plt.grid(True)

# Save the plot as an image file
plt.savefig('../figures/sublinear_time.png', dpi=300)  # Save as PNG with 300 dpi resolution

# Show the plot
plt.show()
